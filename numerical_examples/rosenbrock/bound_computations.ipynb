# %%
import numpy as np

# %%
m = 9_000
delta = 1e-6
eps_m = np.sqrt(np.log(2/delta)/(2*m))
eps_m
# Out:
# np.float64(0.028390782677290234)

# %%
alpha = 0.05
q_idx = 1 - alpha + eps_m
q_idx
# Out:
# np.float64(0.9783907826772902)

# %%
index = int(np.ceil(m * q_idx))
index
# Out:
# 8806
