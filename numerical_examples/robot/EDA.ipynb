# %%
import os

import numpy as np

# %%
os.getcwd()
# Out:
# '/home/rbusetto/meta-glis'

# %%
import numpy as np

data = np.load('data/robot/runs_outputs.npy')
target = np.load('data/robot/runs_targets.npy')

# %%
import matplotlib.pyplot as plt
plt.scatter(data[0, 0, 0], data[0, 0, 1])

# %%
target.shape
# Out:
# (5000, 300)
